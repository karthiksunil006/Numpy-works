# %% [markdown]
# One Hot Encoder
# ================
#
# One Dot Encoder is a encoding mechanism used to convert categorical data into numerical format (0s and 1s)
#
#
# priority      priority_low       priority_medium       priority_high
# ========      ============       ===============       =============
#
# Low              1                      0                    0
#
#
# Medium           0                      1                    0
#
#
# High             0                      0                    1
#
#
#
#
# Label Encoder
# =============
#
#
# priority
# ========
#
# Low          0
#
# Medium       1
#
# High         2

# %%
"""

One Hot Encoder
================

One Dot Encoder is a encoding mechanism used to convert categorical data into numerical format (0s and 1s)


priority      priority_low       priority_medium       priority_high
========      ============       ===============       =============

Low              1                      0                    0


Medium           0                      1                    0


High             0                      0                    1




Label Encoder
=============


priority
========

Low          0

Medium       1

High         2


"""
