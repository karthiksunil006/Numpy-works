# %% [markdown]
# Streamlit
# ============
#
# A package used to convert the python code and machine learning projects into a web application using python only
#
# You can only use stramlit in a .py file
#
# Installation : pip install streamlit
#
# How to run : streamlit run filename.py
