# %%
import math

# %%
math.log(6/10,2)
# Out:
# -0.7369655941662062

# %%
math.log(5/10,2)
# Out:
# -1.0

# %%
math.log(1/4,2)
# Out:
# -2.0

# %%
math.log(2/3,2)
# Out:
# -0.5849625007211563

# %%
math.log(2/3,2)
# Out:
# -0.5849625007211563

# %%
math.log(3/5,2)
# Out:
# -0.7369655941662062
