# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("mushrooms.csv")
df=pd.DataFrame(data)
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
df.groupby("habitat").sum()
# Out:
#                                                      class  \
# habitat
# d        eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# g        eeepeeeepppepeeeeeeeeeeeeeepeeeeeeeeeeeeeeeeee...
# l        pepepeppeppeppppepeeepppeppeepppepepepppeppepp...
# m        eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# p        eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# u        pppeppepepeppeepeeeepeepeeeepeeeepeepepepeeepp...
# w        eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
#
#                                                  cap-shape  \
# habitat
# d        xxxfffxxxfffxxxffxfxfxffxxxxxffxfxxxxxfxxxffxf...
# g        xxxxxbxfxxfbxxxxfbxbfxfxbfxxxxxbxfbxxxfxbxxbfb...
# l        xfxkbfxxkxxxxxxxkffkkcbxfxxxfxxxkkkxkxfxxxxxxx...
# m        bbbbxbbbbxxbxbbxxxbbbbbbxxbbxxxxbbxbxbbbbbbxxb...
# p        xxxfxxfxxfffxfxffffxxxfxfxfxxxxfxxfffxxfxfffxf...
# u        xxxsxxfxsxxxxsxxfsxsxssxssxxxsfffxxsxxxfxsffff...
# w        xfkxxxkfxffffxffxkfkkfffffkxkkffxkfxxkkfxkkfkk...
#
#                                                cap-surface  \
# habitat
# d        sffffssfsssfsfsssffffsfssffsfsfffffffssffffsss...
# g        ssyyysffsysyyyysfssyssyysysyfysssysyssyssyfsyy...
# l        yfyyyfyyyyyfyyyyfgyyyggyfyyyyyyyfyfyfyyyfyyyyy...
# m        ssysysyysyysyyssyssyysyyyyyyssyssyyyyyyssyyyss...
# p        yyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy...
# u        syyfysfyfyfysffyffffyffyffffyffffsffyfyfsfffys...
# w        ysssysyssyyyssyyyyyysysyyssyssssssssysyysyyysy...
#
#                                                  cap-color  \
# habitat
# d        yyyyyywwywwwwywywywwwwwyynwywwynyyynwwwynywyww...
# g        ygywyynwnnwywwnwgwywnwyyynnwgynwwnwynwnywwnyyw...
# l        ncnnwcnnnnennnencwcccwwnnnnccnencwnnnnwncnnnnn...
# m        wwwyyyywwywyyyyyywwyyyywyywwyywywwyyywwywwwyyw...
# p        nyyynnnynnynnnyyyyynnnnynynynnnnnyynynnnnynynn...
# u        nwwgwnnwgnnnwggngnngwgnwnnngwnnggwggngwnwnngnn...
# w        bppebbbnbbbeppeneepnenbnpebebpbbpnbnebbbepbpnb...
#
#                                                    bruises  \
# habitat
# d        tttttttttttttttttttttttttttttttttttttttttttttt...
# g        tfttttffttttttttftttftttttftftftttttftttttfttt...
# l        fffftfffffffffffftfffttfffffffffftfffftfffffff...
# m        tttttttttttttttttttttttttttttttttttttttttttttt...
# p        tttttttttttttttttttttttttttttttttttttttttttttt...
# u        tttfttftftfttfftfffftfftfffftfffftfftftftffftt...
# w        tttttttttttttttttttttttttttttttttttttttttttttt...
#
#                                                       odor  \
# habitat
# d        alallllallalallaaaalallalnaallanalanlalanlalal...
# g        anaplannpppapaalnallnlaaaanpnlnalllanalaaanlll...
# l        fnynnnsfnfynysyynnnnnnnfnyfnnfyfnnnynsnsnfsnss...
# m        lalaaalalalllllalllaallllalaaaallllllaalalalal...
# p        llllaalaaalaallaalaallalaaaalllaaaaaalallaaaal...
# u        pppnppnpnpnppnnpnnnnpnnpnnnnpnnnnpnnpnpnpnnnpp...
# w        nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn...
#
#                                            gill-attachment  \
# habitat
# d        ffffffffffffffffffffffffffffffffffffffffffffff...
# g        ffffffffffffffffffffffffffffffffffffffffffffff...
# l        ffffffffffffffffffffffffffffffffffffffffffffff...
# m        ffffffffffffffffffffffffffffffffffffffffffffff...
# p        ffffffffffffffffffffffffffffffffffffffffffffff...
# u        ffffffffffffffffffffffffffffffffffffffffffffff...
# w        ffffffffffffffffffffffffffffffffffffffffffffff...
#
#                                               gill-spacing  \
# habitat
# d        wwwwwwwwwwwwwwwwwwwwwwwwwcwwwwwcwwwcwwwwcwwwww...
# g        cwccccwwccccccccwcccwcccccwcwcwcccccwcccccwccc...
# l        cwcwwwccwccwccccwwwwwwwcwccwwcccwwwcwcwcwccwcc...
# m        cccccccccccccccccccccccccccccccccccccccccccccc...
# p        cccccccccccccccccccccccccccccccccccccccccccccc...
# u        cccccccccccccccccccccccccccccccccccccccccccccc...
# w        cccccccccccccccccccccccccccccccccccccccccccccc...
#
#                                                  gill-size  \
# habitat
# d        nnnnnnnnnnnnnnnnnnnnnnnnnbnnnnnbnnnbnnnnbnnnnn...
# g        bbbnbbbbnnnbnbbbbbbbbbbbbbbnbbbbbbbbbbbbbbbbbb...
# l        nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn...
# m        bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb...
# p        bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb...
# u        nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn...
# w        bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb...
#
#                                                 gill-color  ...  \
# habitat                                                     ...
# d        nwppwpnwpwpwwnwwnnpwppwpwppwnwwppnpnpnnnnpnnpp...  ...
# g        kknpgwnknnnnpnwknwknknwwknkwnwkwnwkgngpnggpnwg...  ...
# l        bwbwwwbbwbbwbbbbwwwwwwwbwbbwwbbbwwwbwbwbwbbwbb...  ...
# m        ngngnkkwgnwgnnkwkwkwkggggnngknggnwggwgngwwkggg...  ...
# p        pnnwpppnwwwpwnnpwwnwnppwppnwwwnnppnwwnnwnpwwnw...  ...
# u        knkknkkkkwgkkkpwnnngnpkwkkkgpggpgknppnkkngkgww...  ...
# w        eeeeeeeewewwweeewewwweweeweewwwwweewwweweeewww...  ...
#
#                                   stalk-surface-above-ring  \
# habitat
# d        ssssssssssssssssssssssssssssssssssssssssssssss...
# g        ssssssssssssssssssssssssssfsssssssssssssssfsss...
# l        sfsfssskfkksskkkfsfsfssksssfskksfsfssksssssssk...
# m        ssssssssssssssssssssssssssssssssssssssssssssss...
# p        ssssssssssssssssssssssssssssssssssssssssssssss...
# u        ssssssssssssssssssssssssssssssssssssssssssssss...
# w        ssssssssssssssssssssssssssssssssssssssssssssss...
#
#                                   stalk-surface-below-ring  \
# habitat
# d        ssssssssssssssssssssssssssssssssssssssssssssss...
# g        ssssssfsssssssysssssssyssysssysssyssssysssssys...
# l        sfkfsfssskkfskkssssfssskfkkffkssfsfssssssksfss...
# m        ssssssssssssssssssssssssssssssssssssssssssssss...
# p        yyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy...
# u        ssssssssssssssssssssssssssssssssssssssssssssss...
# w        ssssssssssssssssssssssssssssssssssssssssssssss...
#
#                                     stalk-color-above-ring  \
# habitat
# d        wwwwwwwwwwwwwwwwwwwwwwwwwgwwwwwpwwwgwwwwgwwwww...
# g        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# l        pwpwwwppwwpwwwwpwwwwwwwpwwwwwwpwwwwwwwwpwpwwwp...
# m        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# p        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# u        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# w        ewwwwweweewwwwweeweweeewewweeewwewwweweewwwwee...
#
#                                     stalk-color-below-ring  \
# habitat
# d        wwwwwwwwwwwwwwwwwwwwwwwwwpwwwwwwwwwwwwwwpwwwww...
# g        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# l        pnwnwnppnwwnpwwwnwnnnwwpnwwnnpwpnwnwnwwwnpwnpw...
# m        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# p        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# u        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# w        wweeewewwewweweeewewwwwweeweweweewwewewwwweewe...
#
#                                                  veil-type  \
# habitat
# d        pppppppppppppppppppppppppppppppppppppppppppppp...
# g        pppppppppppppppppppppppppppppppppppppppppppppp...
# l        pppppppppppppppppppppppppppppppppppppppppppppp...
# m        pppppppppppppppppppppppppppppppppppppppppppppp...
# p        pppppppppppppppppppppppppppppppppppppppppppppp...
# u        pppppppppppppppppppppppppppppppppppppppppppppp...
# w        pppppppppppppppppppppppppppppppppppppppppppppp...
#
#                                                 veil-color  \
# habitat
# d        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# g        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# l        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# m        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# p        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# u        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# w        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
#
#                                                ring-number  \
# habitat
# d        oooooooooooooooooooooooooooooooooooooooooooooo...
# g        oooooooooooooooooooooooooooooooooooooooooooooo...
# l        oooooooooooooooooooooooooooooooooooooooooooooo...
# m        oooooooooooooooooooooooooooooooooooooooooooooo...
# p        oooooooooooooooooooooooooooooooooooooooooooooo...
# u        oooooooooooooooooooooooooooooooooooooooooooooo...
# w        tttttttttttttttttttttttttttttttttttttttttttttt...
#
#                                                  ring-type  \
# habitat
# d        pppppppppppppppppppppppppppppppppppppppppppppp...
# g        peppppeeppppppppepppepppppepepepppppepppppeppp...
# l        eeeepeeeeeeeeeeeepeeeppeeeeeeeeeepeeeepeeeeeee...
# m        pppppppppppppppppppppppppppppppppppppppppppppp...
# p        pppppppppppppppppppppppppppppppppppppppppppppp...
# u        pppppppppppppppppppppppppppppppppppppppppppppp...
# w        eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
#
#                                          spore-print-color  \
# habitat
# d        nnnnnnuuuunnuunnnnnnuuunnnnnnnuknnununnunnunnu...
# g        nnkknnknknnnnnkknnknkknkknnknkkknkkknnnknkkknn...
# l        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# m        nknkknnnknnnnnkkknnknnnnkkknkknnnnkknkkkkkknnn...
# p        nknkkknkkknknknkkknnnnnknnnnknnnnkknnkknknnnnk...
# u        kknnnnknknknknnnnnnknnnnnknnnnkknnnnkkkkknnkkk...
# w        wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
#
#                                                 population
# habitat
# d        vvvvvvvvvvvvvvvvvvvvvvvvvyvvvvvyvvvyvvvvyvvvvv...
# g        nanvnsaasvvsvnssannsassnsysssssssyssassnsssnsn...
# l        vvvvcvvvvvvvvvvvvcvvvccvvvvvvvvvvcvvvvcvvvvvvv...
# m        nnsssssnsnnnnssnsnnsssnsnnssnnnssssnnnsssnnnss...
# p        yyssysyyyyysyyysyyssysssyyssyysyyyyyssssyysyyy...
# u        ssvyssysvsyvvvvvyvyyvyyvvvyyvyvvyvyvvysvvvvvsv...
# w        cccccccccccccccccccccccccccccccccccccccccccccc...
#
# [7 rows x 22 columns]

# %%
df.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

Le=LabelEncoder()

# df["class"]=Le.fit_transform(df["class"])
# df["cap-shape"]=Le.fit_transform(df["cap-shape"])
# df["cap-surface"]=Le.fit_transform(df["cap-surface"])
# df["cap-color"]=Le.fit_transform(df["cap-color"])
# df["bruises"]=Le.fit_transform(df["bruises"])
# df["odor"]=Le.fit_transform(df["odor"])
# df["gill-attachment"]=Le.fit_transform(df["gill-attachment"])
# df["gill-spacing"]=Le.fit_transform(df["gill-spacing"])
# df["gill-size"]=Le.fit_transform(df["gill-size"])
# df["gill-color"]=Le.fit_transform(df["gill-color"])
# df["stalk-shape"]=Le.fit_transform(df["stalk-shape"])
# df["stalk-root"]=Le.fit_transform(df["stalk-root"])
# df["stalk-surface-above-ring"]=Le.fit_transform(df["stalk-surface-above-ring"])
# df["stalk-surface-below-ring"]=Le.fit_transform(df["stalk-surface-below-ring"])
# df["stalk-color-above-ring"]=Le.fit_transform(df["stalk-color-above-ring"])
# df["stalk-color-below-ring"]=Le.fit_transform(df["stalk-color-below-ring"])
# df["veil-type"]=Le.fit_transform(df["veil-type"])
# df["veil-color"]=Le.fit_transform(df["veil-color"])
# df["ring-number"]=Le.fit_transform(df["ring-number"])
# df["ring-type"]=Le.fit_transform(df["ring-type"])
# df["spore-print-color"]=Le.fit_transform(df["spore-print-color"])
# df["population"]=Le.fit_transform(df["population"])
# df["habitat"]=Le.fit_transform(df["habitat"])

for i in list(df):

    df[i]=Le.fit_transform(df[i])

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# 2                   1             0          0           5  ...
# 3                   1             0          1           5  ...
# 4                   1             1          0           4  ...
# ...               ...           ...        ...         ...  ...
# 8119                0             0          0          11  ...
# 8120                0             0          0          11  ...
# 8121                0             0          0           5  ...
# 8122                1             0          1           0  ...
# 8123                0             0          0          11  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            2                       7
# 1                            2                       7
# 2                            2                       7
# 3                            2                       7
# 4                            2                       7
# ...                        ...                     ...
# 8119                         2                       5
# 8120                         2                       5
# 8121                         2                       5
# 8122                         1                       7
# 8123                         2                       5
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                          7          0           2            1          4
# 1                          7          0           2            1          4
# 2                          7          0           2            1          4
# 3                          7          0           2            1          4
# 4                          7          0           2            1          0
# ...                      ...        ...         ...          ...        ...
# 8119                       5          0           1            1          4
# 8120                       5          0           0            1          4
# 8121                       5          0           1            1          4
# 8122                       7          0           2            1          0
# 8123                       5          0           1            1          4
#
#       spore-print-color  population  habitat
# 0                     2           3        5
# 1                     3           2        1
# 2                     3           2        3
# 3                     2           3        5
# 4                     3           0        1
# ...                 ...         ...      ...
# 8119                  0           1        2
# 8120                  0           4        2
# 8121                  0           1        2
# 8122                  7           4        2
# 8123                  4           1        2
#
# [8124 rows x 23 columns]

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
X
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# 2                   1             0          0           5  ...
# 3                   1             0          1           5  ...
# 4                   1             1          0           4  ...
# ...               ...           ...        ...         ...  ...
# 8119                0             0          0          11  ...
# 8120                0             0          0          11  ...
# 8121                0             0          0           5  ...
# 8122                1             0          1           0  ...
# 8123                0             0          0          11  ...
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 0                            2                         2
# 1                            2                         2
# 2                            2                         2
# 3                            2                         2
# 4                            2                         2
# ...                        ...                       ...
# 8119                         2                         2
# 8120                         2                         2
# 8121                         2                         2
# 8122                         2                         1
# 8123                         2                         2
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                          7                       7          0           2
# 1                          7                       7          0           2
# 2                          7                       7          0           2
# 3                          7                       7          0           2
# 4                          7                       7          0           2
# ...                      ...                     ...        ...         ...
# 8119                       5                       5          0           1
# 8120                       5                       5          0           0
# 8121                       5                       5          0           1
# 8122                       7                       7          0           2
# 8123                       5                       5          0           1
#
#       ring-number  ring-type  spore-print-color  population
# 0               1          4                  2           3
# 1               1          4                  3           2
# 2               1          4                  3           2
# 3               1          4                  2           3
# 4               1          0                  3           0
# ...           ...        ...                ...         ...
# 8119            1          4                  0           1
# 8120            1          4                  0           4
# 8121            1          4                  0           1
# 8122            1          0                  7           4
# 8123            1          4                  4           1
#
# [8124 rows x 22 columns]

# %%
Y
# Out:
# 0       5
# 1       1
# 2       3
# 3       5
# 4       1
#        ..
# 8119    2
# 8120    2
# 8121    2
# 8122    2
# 8123    2
# Name: habitat, Length: 8124, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

knn=knn.fit(X_train,Y_train)

Y_pred=knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(Y_pred,Y_test))
# Out:
# 0.5484003281378179

# %%
Y_pred
# Out:
# array([5, 0, 1, ..., 0, 0, 0], shape=(2438,))

# %%
df.groupby("habitat").sum()
# Out:
#          class  cap-shape  cap-surface  cap-color  bruises   odor  \
# habitat
# 0         1268      11164         5288      12004     1824  13688
# 1          740       6932         3330      12268      660   7908
# 2          592       2584         1936       2752        8   4544
# 3           36        676          730       2332      292    564
# 4         1008       3900         2476       5080      128   4472
# 5          272       1304          608       1632      272   1536
# 6            0        640          480        528      192    960
#
#          gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# habitat                                                        ...
# 0                   3130           192        944       18054  ...
# 1                   2148          1056        128       11280  ...
# 2                    640            64        640        2052  ...
# 3                    292             0          0        1584  ...
# 4                   1144             0        576        2832  ...
# 5                    368             0        224        2224  ...
# 6                    192             0          0        1056  ...
#
#          stalk-surface-above-ring  stalk-surface-below-ring  \
# habitat
# 0                            5516                      5556
# 1                            2808                      2904
# 2                            1336                      1336
# 3                             584                       584
# 4                            1576                      1672
# 5                             592                       592
# 6                             384                       384
#
#          stalk-color-above-ring  stalk-color-below-ring  veil-type  \
# habitat
# 0                         17044                   17012          0
# 1                         13452                   13452          0
# 2                          5160                    5016          0
# 3                          2044                    2044          0
# 4                          6112                    6112          0
# 5                          2576                    2576          0
# 6                           864                     864          0
#
#          veil-color  ring-number  ring-type  spore-print-color  population
# habitat
# 0              6296         3120       9116              10276       13500
# 1              4296         2472       4656               5892        5936
# 2              1384          832        800               5200        2992
# 3               584          328       1168                820         784
# 4              2288         1184       1408               4984        4816
# 5               736          368       1472                704        1384
# 6               384          384          0               1344         192
#
# [7 rows x 22 columns]
