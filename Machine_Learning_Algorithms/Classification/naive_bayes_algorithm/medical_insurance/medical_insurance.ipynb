# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("medical_insurance.csv")
df=pd.DataFrame(data)
df
# Out:
#        person_id  age     sex   region urban_rural    income     education  \
# 0          75722   52  Female    North    Suburban   22700.0     Doctorate
# 1          80185   79  Female    North       Urban   12800.0         No HS
# 2          19865   68    Male    North       Rural   40700.0            HS
# 3          76700   15    Male    North    Suburban   15600.0  Some College
# 4          92992   53    Male  Central    Suburban   89600.0     Doctorate
# ...          ...  ...     ...      ...         ...       ...           ...
# 99995       6266   50    Male     West       Urban  127200.0         No HS
# 99996      54887   42    Male     East    Suburban   21600.0            HS
# 99997      76821   41    Male     West       Rural   81900.0            HS
# 99998        861   51  Female    South       Urban   43400.0     Doctorate
# 99999      15796   44  Female    South       Rural   43700.0  Some College
#
# ...

# %%
df=df.drop(columns=["person_id","sex","region","education"],axis=1)
df
# Out:
#        age urban_rural    income marital_status employment_status  \
# 0       52    Suburban   22700.0        Married           Retired
# 1       79       Urban   12800.0        Married          Employed
# 2       68       Rural   40700.0        Married           Retired
# 3       15    Suburban   15600.0        Married     Self-employed
# 4       53    Suburban   89600.0        Married     Self-employed
# ...    ...         ...       ...            ...               ...
# 99995   50       Urban  127200.0        Married          Employed
# 99996   42    Suburban   21600.0        Married          Employed
# 99997   41       Rural   81900.0       Divorced        Unemployed
# 99998   51       Urban   43400.0         Single        Unemployed
# 99999   44       Rural   43700.0        Married          Employed
#
#        household_size  dependents   bmi  smoker alcohol_freq  ...  \
# 0                   3           1  27.4   Never          NaN  ...
# ...

# %%
df.isna().sum()
# Out:
# age                                0
# urban_rural                        0
# income                             0
# marital_status                     0
# employment_status                  0
# household_size                     0
# dependents                         0
# bmi                                0
# smoker                             0
# alcohol_freq                   30083
# visits_last_year                   0
# hospitalizations_last_3yrs         0
# days_hospitalized_last_3yrs        0
# medication_count                   0
# systolic_bp                        0
# diastolic_bp                       0
# ldl                                0
# hba1c                              0
# plan_type                          0
# network_tier                       0
# deductible                         0
# copay                              0
# policy_term_years                  0
# policy_changes_last_2yrs           0
# provider_quality                   0
# ...

# %%
df.dtypes
# Out:
# age                              int64
# urban_rural                     object
# income                         float64
# marital_status                  object
# employment_status               object
# household_size                   int64
# dependents                       int64
# bmi                            float64
# smoker                          object
# alcohol_freq                    object
# visits_last_year                 int64
# hospitalizations_last_3yrs       int64
# days_hospitalized_last_3yrs      int64
# medication_count                 int64
# systolic_bp                    float64
# diastolic_bp                   float64
# ldl                            float64
# hba1c                          float64
# plan_type                       object
# network_tier                    object
# deductible                       int64
# copay                            int64
# policy_term_years                int64
# policy_changes_last_2yrs         int64
# ...

# %%
df["alcohol_freq"]=df["alcohol_freq"].fillna(df["alcohol_freq"].mode()[0])

# %%
df.isna().sum()
# Out:
# age                            0
# urban_rural                    0
# income                         0
# marital_status                 0
# employment_status              0
# household_size                 0
# dependents                     0
# bmi                            0
# smoker                         0
# alcohol_freq                   0
# visits_last_year               0
# hospitalizations_last_3yrs     0
# days_hospitalized_last_3yrs    0
# medication_count               0
# systolic_bp                    0
# diastolic_bp                   0
# ldl                            0
# hba1c                          0
# plan_type                      0
# network_tier                   0
# deductible                     0
# copay                          0
# policy_term_years              0
# policy_changes_last_2yrs       0
# provider_quality               0
# risk_score                     0
# annual_medical_cost            0
# annual_premium                 0
# ...

# %%
df.dtypes
# Out:
# age                              int64
# urban_rural                     object
# income                         float64
# marital_status                  object
# employment_status               object
# household_size                   int64
# dependents                       int64
# bmi                            float64
# smoker                          object
# alcohol_freq                    object
# visits_last_year                 int64
# hospitalizations_last_3yrs       int64
# days_hospitalized_last_3yrs      int64
# medication_count                 int64
# systolic_bp                    float64
# diastolic_bp                   float64
# ldl                            float64
# hba1c                          float64
# plan_type                       object
# network_tier                    object
# deductible                       int64
# copay                            int64
# policy_term_years                int64
# policy_changes_last_2yrs         int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

Le=LabelEncoder()

for i in list(df):

    if df[i].dtypes == 'object':

        df[i]=Le.fit_transform(df[i].astype(str))

# %%
df.dtypes
# Out:
# age                              int64
# urban_rural                      int64
# income                         float64
# marital_status                   int64
# employment_status                int64
# household_size                   int64
# dependents                       int64
# bmi                            float64
# smoker                           int64
# alcohol_freq                     int64
# visits_last_year                 int64
# hospitalizations_last_3yrs       int64
# days_hospitalized_last_3yrs      int64
# medication_count                 int64
# systolic_bp                    float64
# diastolic_bp                   float64
# ldl                            float64
# hba1c                          float64
# plan_type                        int64
# network_tier                     int64
# deductible                       int64
# copay                            int64
# policy_term_years                int64
# policy_changes_last_2yrs         int64
# ...

# %%
Y=df.iloc[:,48]
df=df.drop(columns=["is_high_risk"],axis=1)

X=df

# %%
X
# Out:
#        age  urban_rural    income  marital_status  employment_status  \
# 0       52            1   22700.0               1                  1
# 1       79            2   12800.0               1                  0
# 2       68            0   40700.0               1                  1
# 3       15            1   15600.0               1                  2
# 4       53            1   89600.0               1                  2
# ...    ...          ...       ...             ...                ...
# 99995   50            2  127200.0               1                  0
# 99996   42            1   21600.0               1                  0
# 99997   41            0   81900.0               0                  3
# 99998   51            2   43400.0               2                  3
# 99999   44            0   43700.0               1                  0
#
#        household_size  dependents   bmi  smoker  alcohol_freq  ...  \
# 0                   3           1  27.4       2             1  ...
# ...

# %%
Y
# Out:
# 0        0
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: is_high_risk, Length: 100000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier


knn=KNeighborsClassifier()

knn=knn.fit(X_train,Y_train)

Y_pred=knn.predict(X_test)

# %%
# from sklearn.naive_bayes import GaussianNB

# nb=GaussianNB()

# nb=nb.fit(X_train,Y_train)

# Y_pred=nb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.8838666666666667

# %% [markdown]
# Using Knn >> Accuracy >> o.88
#
# Using Naive Bayes  >>> Accuracy  >> 0.83
