# %% [markdown]
# Hyper Parameter Tuning
# ======================
#
#
# The settings which are given to the model before training
# they decide how the model learns
#
# >> knn   k=5   k=7
# >> Random forest   n_estimators=100   300   1000
#
#
# Trying different combinationof hyper parameter and selecting the best one
