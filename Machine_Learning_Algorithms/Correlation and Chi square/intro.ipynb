# %% [markdown]
# Correlation and Chi Square
#
# correlation
# ===========
# df.corr()  to get the relation among numerical columns  if above 0.5 that column is important and should not be dropped
#
#
# Chi Square
# ==========
# To get the relation among object columns
