# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Student_Performance.csv")
df=pd.DataFrame(data)
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

df["Extracurricular Activities"]=le.fit_transform(df["Extracurricular Activities"])

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities            int64
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()

lr=lr.fit(X_train,Y_train)

Y_pred=lr.predict(X_test)

# %%
Y_pred
# Out:
# array([65.44076133, 84.35074985, 45.22894641, ..., 82.23278582,
#        37.17591089, 67.46751201], shape=(3000,))

# %%
Y_test
# Out:
# 2702    65.0
# 5121    82.0
# 9299    45.0
# 2718    38.0
# 7837    15.0
#         ...
# 5466    53.0
# 8352    22.0
# 9231    82.0
# 7142    35.0
# 4063    71.0
# Name: Performance Index, Length: 3000, dtype: float64

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score

print(f"Mean_Absolute_Percentage_Error = {mean_absolute_percentage_error(Y_test,Y_pred)}")

print(f"R2_Score = {r2_score(Y_test,Y_pred)}")
# Out:
# Mean_Absolute_Percentage_Error = 0.034171034048780705
# R2_Score = 0.9889580647098742

# %%
print(f"m = {lr.coef_}")
# Out:
# m = [ 7.33668578 17.71382185  0.29635876  0.78207438  0.53788968]

# %%
print(f"c = {lr.intercept_}")
# Out:
# c = 55.241285714285716
