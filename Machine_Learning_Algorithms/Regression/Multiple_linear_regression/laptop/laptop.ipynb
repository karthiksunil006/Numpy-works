# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Laptop_price.csv")
df=pd.DataFrame(data)
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# 3    4.573865  17436.728334
# 4    4.193472  32917.990718
# ..        ...           ...
# 995  3.162399  31593.668017
# 996  3.750265   9149.521832
# 997  3.392612  16552.404779
# 998  3.857613   9407.473459
# 999  3.440883   8807.696702
#
# [1000 rows x 7 columns]

# %%
df.dtypes
# Out:
# Brand                object
# Processor_Speed     float64
# RAM_Size              int64
# Storage_Capacity      int64
# Screen_Size         float64
# Weight              float64
# Price               float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

df["Brand"]=le.fit_transform(df["Brand"])

# %%
df.dtypes
# Out:
# Brand                 int64
# Processor_Speed     float64
# RAM_Size              int64
# Storage_Capacity      int64
# Screen_Size         float64
# Weight              float64
# Price               float64
# dtype: object

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()

lr=lr.fit(X_train,Y_train)

Y_pred=lr.predict(X_test)

# %%
print(f"m = {lr.coef_}")
print(f"c = {lr.intercept_}")
# Out:
# m = [-2.08435750e+00  1.48203792e+02  5.55509497e+02  9.21877176e+03
#   2.86725135e+01 -2.37952042e+00]
# c = 19315.62122173587

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score

print(f"Mean_Absolute_Percentage_Error = {mean_absolute_percentage_error(Y_test,Y_pred)}")
print(f"R2_Score = {r2_score(Y_test,Y_pred)}")
# Out:
# Mean_Absolute_Percentage_Error = 0.00978918857579061
# R2_Score = 0.999576755181499
