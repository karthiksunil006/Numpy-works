# %%
from matplotlib import pyplot

area=[2600,2800,3100,3400,3800]
price=[5600000,5800000,6100000,6600000,7200000]


pyplot.scatter(area,price,label="data points")
pyplot.xlabel("Area")
pyplot.ylabel("Price")
pyplot.title("Area v/s Price")
pyplot.legend()
pyplot.show()

# %% [markdown]
# Equation : y = mx + c
#
#           x = input
#           m = slope
#           c = intercept
#
#           y = output predicted
#
#
#           We need to find the best m and c values
